# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from termcolor import colored
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
import seaborn as sb

# %%
data = pd.read_csv("Leukemia.csv")
data['type'].unique()
# Out:
# array(['Bone_Marrow_CD34', 'Bone_Marrow', 'AML', 'PB', 'PBSC_CD34'],
#       dtype=object)

# %%
y = data['type']
x = data.drop('type', axis = 'columns')

# %%
x
# Out:
#     samples  1007_s_at   1053_at     117_at    121_at  1255_g_at   1294_at  \
# 0         1   7.745245  7.811210   6.477916  8.841506   4.546941  7.957714
# 1        12   8.087252  7.240673   8.584648  8.983571   4.548934  8.011652
# 2        13   7.792056  7.549368  11.053504  8.909703   4.549328  8.237099
# 3        14   7.767265  7.094460  11.816433  8.994654   4.697018  8.283412
# 4        15   8.010117  7.405281   6.656049  9.050682   4.514986  8.377046
# ..      ...        ...       ...        ...       ...        ...       ...
# 59       60   7.686106  6.856961   6.822222  8.849700   4.440703  8.456949
# 60       61   7.816168  6.875124   6.532324  8.827857   4.515457  8.450286
# 61       62   7.863092  6.896242   6.630690  8.775139   4.458048  8.664517
# 62       63   7.900992  6.787515   6.642927  8.856187   4.499548  9.188459
# 63       64   8.004488  6.657433   6.705597  8.778333   4.599833  8.701859
#
#      1316_at   1320_at  1405_i_at  ...  AFFX-r2-Hs28SrRNA-5_at  \
# 0   5.344999  4.673364   4.664924  ...                5.058849
# 1   5.579647  4.828184   5.171835  ...                4.436153
# 2   5.406489  4.615572   4.775709  ...                4.392061
# 3   5.582195  4.903684   4.829844  ...                4.633334
# 4   5.493713  4.860754   5.245049  ...                5.305192
# ..       ...       ...        ...  ...                     ...
# 59  5.408897  4.708615   4.691377  ...                4.969400
# 60  5.482797  4.667874   4.968642  ...                4.826255
# 61  5.577298  4.853996   4.815901  ...                5.065816
# 62  5.471110  4.637444   5.036441  ...                4.985061
# 63  5.481296  4.640955   4.830320  ...                4.707060
#
#     AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0                 6.810004            12.800060            12.718612
# 1                 6.751471            12.472706            12.333593
# 2                 6.086295            12.637384            12.499038
# 3                 6.375991            12.903630            12.871454
# 4                 6.700453            12.949352            12.782515
# ..                     ...                  ...                  ...
# 59                7.016576            12.997293            12.828832
# 60                6.577223            12.990305            12.855352
# 61                6.583261            12.786121            12.588852
# 62                6.815527            13.020089            12.824868
# 63                6.454188            12.994600            12.845402
#
#     AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# 0         5.391512        4.666166        3.974759         3.656693
# 1         5.379738        4.656786        4.188348         3.792535
# 2         5.316604        4.600566        3.845561         3.635715
# 3         5.179951        4.641952        3.991634         3.704587
# 4         5.341689        4.560315        3.887020         3.629853
# ..             ...             ...             ...              ...
# 59        5.084120        4.531087        3.884230         3.619301
# 60        5.260451        4.568651        3.927693         3.634879
# 61        5.451940        4.739944        4.010427         3.668713
# 62        5.459571        4.602105        4.019624         3.570563
# 63        5.371230        4.618882        3.978051         3.638367
#
#     AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# 0          4.160622         4.139249
# 1          4.204414         4.122700
# 2          4.174199         4.067152
# 3          4.149938         3.910150
# 4          4.127513         4.004316
# ..              ...              ...
# 59         4.108490         4.070028
# 60         4.112277         4.064780
# 61         4.162220         4.102264
# 62         4.141371         4.102641
# 63         4.156842         4.179867
#
# [64 rows x 22284 columns]

# %% [markdown]
# Izbacujemo kolonu sa tipovima leukemije jer je to nasa ciljnja kolona, ali je cuvamo kako bi kasnijemogli da radimo proveru

# %%
y.replace("AML", 0, inplace = True)
y.replace("Bone_Marrow", 1, inplace = True)
y.replace("Bone_Marrow_CD34", 2, inplace = True)
y.replace("PB", 3, inplace = True)
y.replace("PBSC_CD34", 4, inplace = True)
y.unique()
# Out:
# array([2, 1, 0, 3, 4])

# %% [markdown]
# - 0 -> AML
# - 1 -> Bone_Marrow
# - 2 -> Bone_Marrow_CD34
# - 3 -> PB
# - 4 -> PBSC_CD34

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# Podatke i njihove labele (tipove) smo podelili na train i test skupove

# %%
x_train
# Out:
#     samples  1007_s_at   1053_at     117_at    121_at  1255_g_at   1294_at  \
# 13        7   7.720314  6.583612   6.756619  8.845196   4.477831  8.064107
# 34       35   7.565505  6.387039   6.943786  8.961879   4.512782  9.072825
# 50       51   7.679455  6.535146   8.598109  8.591818   4.380294  8.183958
# 3        14   7.767265  7.094460  11.816433  8.994654   4.697018  8.283412
# 17       11   7.813454  6.794223   6.576484  8.904530   4.506871  7.893402
# 49       50   8.021694  6.286823   8.952662  8.862089   4.585165  8.280266
# 8         2   7.966060  6.781246   6.920990  8.978862   4.478028  7.683032
# 6        17   8.167701  6.949900   7.604404  9.326422   4.754915  7.331400
# 33       34   7.760597  6.511641   6.798202  9.061344   4.467035  8.097595
# 4        15   8.010117  7.405281   6.656049  9.050682   4.514986  8.377046
# 47       48   7.829496  6.696525   9.132156  8.555248   4.554677  8.191480
# 19       20   8.016039  6.792462   7.124946  8.934684   4.532554  8.232283
# 54       55   7.921690  6.604476   6.731894  9.107751   4.479954  8.881759
# 41       42   7.887302  6.541554   6.677695  9.137187   4.587700  7.957291
# 55       56   8.006753  6.968522   6.511047  8.956752   4.488530  8.678104
# 31       32   7.833074  6.444448   6.422178  8.866566   4.642514  8.171570
# 30       31   7.648361  6.941281   6.681016  9.150922   4.567999  8.785498
# 59       60   7.686106  6.856961   6.822222  8.849700   4.440703  8.456949
# 60       61   7.816168  6.875124   6.532324  8.827857   4.515457  8.450286
# 15        9   7.879563  6.461114   6.825904  8.821318   4.442335  8.210984
# 27       28   7.990804  6.979258   6.718807  9.355733   4.590992  8.549266
# 26       27   7.952027  6.198108   7.505293  9.022825   4.702510  7.774656
# 24       25   7.568038  6.923743   7.024682  8.843674   4.519772  8.976736
# 46       47   7.902043  6.456723   9.055041  8.599191   4.394315  8.229724
# 11        5   7.748487  6.771069   6.651201  8.689840   4.490658  7.964260
# 32       33   7.765633  6.561750   6.733191  8.864177   4.568688  8.329480
# 57       58   7.573025  6.825199   6.494179  8.898793   4.356424  8.720641
# 45       46   7.780909  6.703551   9.344910  8.734230   4.365734  8.230329
# 37       38   7.979248  6.233277   7.655962  9.156432   4.696280  8.105200
# 29       30   7.671982  6.619427   6.828523  8.875449   4.384878  8.452299
# 43       44   8.028411  6.401388   6.566925  8.899167   4.496918  8.988340
# 59         4.108490         4.070028
# 60         4.112277         4.064780
# 15         4.186596         4.132372
# 27         4.144790         4.104532
# 26         4.240349         4.196429
# 24         4.322709         4.460656
# 46         4.248523         4.069873
# 11         4.127753         4.084930
# 32         4.116434         4.041620
# 57         4.002839         4.016314
# 45         4.113644         4.117213
# 37         4.110579         4.063482
# 29         4.045278         4.153341
# 43         4.043314         3.953080
# 48         4.206121         4.103831
# 1          4.204414         4.122700
# 21         4.163532         4.164099
# 2          4.174199         4.067152
# 62         4.141371         4.102641
# 39         4.079608         4.175031
# 35         4.066095         4.138597
# 23         4.330157         4.301198
# 53         4.170482         4.057474
# 10         4.127582         4.082404
# 22         4.065834         4.175163
# 18         4.045644         4.084770
# 63         4.156842         4.179867
# 20         4.213720         4.264922
# 7          4.069378         4.083583
# 42         4.203593         4.122285
# 14         4.080418         4.073512
# 28         4.122995         4.100526
# 51         4.097252         3.962155
# 38         4.090078         4.133423
#
# [51 rows x 22284 columns]

# %% [markdown]
# # Sada mozemo napraviti prvu verziju naseg stabla odlucivanja

# %%
tree1 = DecisionTreeClassifier()
model = tree1.fit(x_train, y_train)

# %%
def report(model, x, y, text = 'training'):
    y_pred = model.predict(x)
    
    print(colored("Classification report for model {} on {} data".format(type(model).__name__, text), "green"))
    print("---------------------------------------------------------------------------------")
    print(classification_report(y, y_pred))
    print("---------------------------------------------------------------------------------")
    
    print(colored("Confusion matrix for model {} on {} data ".format(type(model).__name__, text), "green"))
    print("---------------------------------------------------------------------------------")
    print(pd.DataFrame(confusion_matrix(y, y_pred), columns=[0, 1, 2, 3, 4], index=[0, 1, 2, 3, 4]))
    print("---------------------------------------------------------------------------------")

def plot_decision_tree(model, names):
    plt.figure(figsize= (7, 7))
    plot_tree(model, class_names=['0', '1', '2', '3', '4'], feature_names=names, filled=True)
    plt.title("Decision tree of depth {} with {} nodes".format(model.get_depth(), model.get_n_leaves()))

    plt.show()
    print("---------------------------------------------------------------------------------")
    print(colored("Parameters of model {}".format(type(model).__name__), "green"))
    for k, v in model.get_params().items():
        print(colored(k, 'blue'), v)
    
    print("---------------------------------------------------------------------------------")

# %%
plt.figure()
plot_decision_tree(tree1, list(x.columns))
plt.show()
# Out:
# ---------------------------------------------------------------------------------
# Parameters of model DecisionTreeClassifier
# ccp_alpha 0.0
# class_weight None
# criterion gini
# max_depth None
# max_features None
# max_leaf_nodes None
# min_impurity_decrease 0.0
# min_samples_leaf 1
# min_samples_split 2
# min_weight_fraction_leaf 0.0
# random_state None
# splitter best
# ---------------------------------------------------------------------------------

# %%
feat_importances = pd.Series(tree1.feature_importances_, index=x.columns)
feat_importances.nlargest(20).plot(kind = 'barh')
plt.title("Feature importance")
plt.show()

# %% [markdown]
# Naravno, nas model i koristi samo ovih 5 atributa kako bi doneo odluku, tako da samo i njima daje ikakav znacaj.

# %%
report(tree1, x_train, y_train)
# Out:
# Classification report for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         8
#            4       1.00      1.00      1.00         7
#
#     accuracy                           1.00        51
#    macro avg       1.00      1.00      1.00        51
# weighted avg       1.00      1.00      1.00        51
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#     0  1  2  3  4
# 0  23  0  0  0  0
# 1   0  7  0  0  0
# 2   0  0  6  0  0
# 3   0  0  0  8  0
# 4   0  0  0  0  7
# ---------------------------------------------------------------------------------

# %%
report(tree1, x_test, y_test)
# Out:
# Classification report for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75         3
#            1       0.67      0.67      0.67         3
#            2       0.50      0.50      0.50         2
#            3       1.00      1.00      1.00         2
#            4       1.00      0.33      0.50         3
#
#     accuracy                           0.69        13
#    macro avg       0.75      0.70      0.68        13
# weighted avg       0.75      0.69      0.67        13
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#    0  1  2  3  4
# 0  3  0  0  0  0
# 1  0  2  1  0  0
# 2  1  0  1  0  0
# 3  0  0  0  2  0
# 4  1  1  0  0  1
# ---------------------------------------------------------------------------------

# %% [markdown]
# Ovako naivan model ima preciznost skoro 70%, ali to mozda mozemo popraviti detaljnijim podesavanjem hiper-parametara

# %%
def matConf(model, x, y):
    y_pred = model.predict(x)
    return confusion_matrix(y, y_pred)

akws = {'c': 'red'}

# %%
sb.heatmap(matConf(tree1, x_test, y_test), xticklabels = ["AML", "Bone_Marrow", "Bone_Marrow_CD34", "PB", "PBSC_CD34"], yticklabels = ["true AML", "true Bone_Marrow", "true Bone_Marrow_CD34", "true PB", "true PBSC_CD34"], annot = True, annot_kws = akws, fmt = 'g', vmin = 0, vmax = 3)
# Out:
# <Axes: >

# %%
params = {'criterion': ['gini', 'entropy'],
          'max_depth': [2, 4, 6, 8]
         }

# %%
estimator = GridSearchCV(DecisionTreeClassifier(), params, n_jobs = 32)

# %%
estimator.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=32,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 4, 6, 8]})

# %%
estimator.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 8}

# %%
estimator.best_score_
# Out:
# 0.7854545454545454

# %%
report(estimator.best_estimator_, x_train, y_train)
# Out:
# Classification report for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         8
#            4       1.00      1.00      1.00         7
#
#     accuracy                           1.00        51
#    macro avg       1.00      1.00      1.00        51
# weighted avg       1.00      1.00      1.00        51
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#     0  1  2  3  4
# 0  23  0  0  0  0
# 1   0  7  0  0  0
# 2   0  0  6  0  0
# 3   0  0  0  8  0
# 4   0  0  0  0  7
# ---------------------------------------------------------------------------------

# %%
report(estimator.best_estimator_, x_test, y_test, "test")
# Out:
# Classification report for model DecisionTreeClassifier on test data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         3
#            1       0.75      1.00      0.86         3
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         3
#
#     accuracy                           0.92        13
#    macro avg       0.95      0.93      0.93        13
# weighted avg       0.94      0.92      0.92        13
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on test data
# ---------------------------------------------------------------------------------
#    0  1  2  3  4
# 0  2  1  0  0  0
# 1  0  3  0  0  0
# 2  0  0  2  0  0
# 3  0  0  0  2  0
# 4  0  0  0  0  3
# ---------------------------------------------------------------------------------

# %%
tree2 = estimator.best_estimator_

# %%
plt.figure()
plot_decision_tree(tree2, list(x.columns))
plt.show()
# Out:
# ---------------------------------------------------------------------------------
# Parameters of model DecisionTreeClassifier
# ccp_alpha 0.0
# class_weight None
# criterion entropy
# max_depth 8
# max_features None
# max_leaf_nodes None
# min_impurity_decrease 0.0
# min_samples_leaf 1
# min_samples_split 2
# min_weight_fraction_leaf 0.0
# random_state None
# splitter best
# ---------------------------------------------------------------------------------

# %%
feat_importances = pd.Series(tree2.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind = 'barh')
plt.title("Feature importance")
plt.show()

# %% [markdown]
# Model pridaje znacaj samo ovim atributima, a najveci znacaj daje 210976_s_at.

# %%
report(tree2, x_train, y_train)
# Out:
# Classification report for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         8
#            4       1.00      1.00      1.00         7
#
#     accuracy                           1.00        51
#    macro avg       1.00      1.00      1.00        51
# weighted avg       1.00      1.00      1.00        51
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#     0  1  2  3  4
# 0  23  0  0  0  0
# 1   0  7  0  0  0
# 2   0  0  6  0  0
# 3   0  0  0  8  0
# 4   0  0  0  0  7
# ---------------------------------------------------------------------------------

# %%
report(tree2, x_test, y_test)
# Out:
# Classification report for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         3
#            1       0.75      1.00      0.86         3
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         3
#
#     accuracy                           0.92        13
#    macro avg       0.95      0.93      0.93        13
# weighted avg       0.94      0.92      0.92        13
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#    0  1  2  3  4
# 0  2  1  0  0  0
# 1  0  3  0  0  0
# 2  0  0  2  0  0
# 3  0  0  0  2  0
# 4  0  0  0  0  3
# ---------------------------------------------------------------------------------

# %% [markdown]
# Ovaj model ima preciznost 92%.

# %%
sb.heatmap(matConf(tree2, x_test, y_test), xticklabels = ["AML", "Bone_Marrow", "Bone_Marrow_CD34", "PB", "PBSC_CD34"], yticklabels = ["true AML", "true Bone_Marrow", "true Bone_Marrow_CD34", "true PB", "true PBSC_CD34"], annot = True, annot_kws = akws, fmt = 'g', vmin = 0, vmax = 3)
# Out:
# <Axes: >

# %% [markdown]
# ## Sta bi se desilo kada bi prvom modelu izbacili svih 5 atributa kojima je dao znacaj?

# %%
x_train2 = x_train.drop('200944_s_at', axis = 'columns')
x_train2 = x_train.drop('214039_s_at', axis = 'columns')
x_train2 = x_train.drop('207943_x_at', axis = 'columns')
x_train2 = x_train.drop('214022_s_at', axis = 'columns')
x_train2 = x_train.drop('202478_at', axis = 'columns')
x_test2 = x_test.drop('200944_s_at', axis = 'columns')
x_test2 = x_test.drop('214039_s_at', axis = 'columns')
x_test2 = x_test.drop('207943_x_at', axis = 'columns')
x_test2 = x_test.drop('214022_s_at', axis = 'columns')
x_test2 = x_test.drop('202478_at', axis = 'columns')

# %%
tree3 = DecisionTreeClassifier()
model = tree3.fit(x_train2, y_train)

# %%
plt.figure()
plot_decision_tree(tree3, list(x.columns))
plt.show()
# Out:
# ---------------------------------------------------------------------------------
# Parameters of model DecisionTreeClassifier
# ccp_alpha 0.0
# class_weight None
# criterion gini
# max_depth None
# max_features None
# max_leaf_nodes None
# min_impurity_decrease 0.0
# min_samples_leaf 1
# min_samples_split 2
# min_weight_fraction_leaf 0.0
# random_state None
# splitter best
# ---------------------------------------------------------------------------------

# %%
report(tree3, x_train2, y_train)
# Out:
# Classification report for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         8
#            4       1.00      1.00      1.00         7
#
#     accuracy                           1.00        51
#    macro avg       1.00      1.00      1.00        51
# weighted avg       1.00      1.00      1.00        51
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#     0  1  2  3  4
# 0  23  0  0  0  0
# 1   0  7  0  0  0
# 2   0  0  6  0  0
# 3   0  0  0  8  0
# 4   0  0  0  0  7
# ---------------------------------------------------------------------------------

# %%
report(tree3, x_test2, y_test)
# Out:
# Classification report for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         3
#            1       0.50      1.00      0.67         3
#            2       1.00      0.50      0.67         2
#            3       0.67      1.00      0.80         2
#            4       1.00      0.67      0.80         3
#
#     accuracy                           0.69        13
#    macro avg       0.83      0.70      0.69        13
# weighted avg       0.83      0.69      0.68        13
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model DecisionTreeClassifier on training data
# ---------------------------------------------------------------------------------
#    0  1  2  3  4
# 0  1  1  0  1  0
# 1  0  3  0  0  0
# 2  0  1  1  0  0
# 3  0  0  0  2  0
# 4  0  1  0  0  2
# ---------------------------------------------------------------------------------

# %% [markdown]
# Vratili smo se na preciznost 70%

# %%
sb.heatmap(matConf(tree3, x_test2, y_test), xticklabels = ["AML", "Bone_Marrow", "Bone_Marrow_CD34", "PB", "PBSC_CD34"], yticklabels = ["true AML", "true Bone_Marrow", "true Bone_Marrow_CD34", "true PB", "true PBSC_CD34"], annot = True, annot_kws = akws, fmt = 'g', vmin = 0, vmax = 3)
# Out:
# <Axes: >

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
parametri = {
    'n_estimators': [100, 200, 300, 400],
    'max_depth':    [5, 10, 15],
    'min_samples_split': [2, 5, 10]
}
estimator2 = GridSearchCV(RandomForestClassifier(), parametri, cv = 5)

# %%
estimator2.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300, 400]})

# %%
print(estimator2.best_score_)
print(estimator2.best_params_)
# Out:
# 1.0
# {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 300}

# %%
report(estimator2.best_estimator_, x_train, y_train,text = "train")
report(estimator2.best_estimator_, x_train, y_train,text = "test")
# Out:
# Classification report for model RandomForestClassifier on train data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         8
#            4       1.00      1.00      1.00         7
#
#     accuracy                           1.00        51
#    macro avg       1.00      1.00      1.00        51
# weighted avg       1.00      1.00      1.00        51
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model RandomForestClassifier on train data
# ---------------------------------------------------------------------------------
#     0  1  2  3  4
# 0  23  0  0  0  0
# 1   0  7  0  0  0
# 2   0  0  6  0  0
# 3   0  0  0  8  0
# 4   0  0  0  0  7
# ---------------------------------------------------------------------------------
# Classification report for model RandomForestClassifier on test data
# ---------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         8
#            4       1.00      1.00      1.00         7
#
#     accuracy                           1.00        51
#    macro avg       1.00      1.00      1.00        51
# weighted avg       1.00      1.00      1.00        51
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model RandomForestClassifier on test data
# ---------------------------------------------------------------------------------
#     0  1  2  3  4
# 0  23  0  0  0  0
# 1   0  7  0  0  0
# 2   0  0  6  0  0
# 3   0  0  0  8  0
# 4   0  0  0  0  7
# ---------------------------------------------------------------------------------

# %%
sb.heatmap(matConf(estimator2, x_test, y_test), xticklabels = ["AML", "Bone_Marrow", "Bone_Marrow_CD34", "PB", "PBSC_CD34"], yticklabels = ["true AML", "true Bone_Marrow", "true Bone_Marrow_CD34", "true PB", "true PBSC_CD34"], annot = True, annot_kws = akws, fmt = 'g', vmin = 0, vmax = 3)
# Out:
# <Axes: >
